# %%
import Task1
import Task2
import Task3

# regression task
task_1 = Task1.Task1()
task_1.model_1_run()
task_1.model_2_run()

# multi-category task
task_2 = Task2.Task2()
task_2.model_1_run()
task_2.model_2_run()

# multi-label task
task_3 = Task3.Task3()
task_3.model_1_run()
task_3.model_2_run()
# Out:
# ================Task 1================
# Model 1:
# print the performance of learned model 1 on testing data here
# [11.21885908 10.44552026 13.25501637 14.45166959 14.2814541   8.39037283
#  13.74506554 13.70762655 13.43661971 12.42685668 14.49775309 13.67289625
#  11.51110979 14.15496521 10.85945895  9.07706842 13.1250913  13.84232508
#  13.24256715 10.06166578  9.29273701 12.17071836 12.91421688 13.49078007
#  13.54225408  9.3611636  12.51675471 10.02939572 13.92599937 10.88298357
#  11.74102651 12.85411428 14.9198578  12.87627312 13.21388144 15.46384598
#  12.53501629 11.55615967 12.8632148  12.51004771 14.25608009 12.69089525
#  12.26492881 12.07263341 11.27842527 14.45249401 12.33989777 13.22292051
#  13.84123064 12.21739521 13.94736923 12.13210978 11.2432315  12.25381517
#  10.56256651 11.13196774 12.97505159 12.15356726 13.54409835 12.25208589
#  14.77057639 11.17939096 12.35733647 13.50686213]
# Coefficients:
# ...
